# %%
class myclass:
    def aval(self):
        q=self.adad/2
        for i in range(1,q+1):
            if self.adad % i == 0 :

# %%
def d1(s):
    f=[]
    for i in s:
        if i not in f:
            f.append(i) 
    return f
print(d1([1,2,3,1,4,5,6,2,9,6,0,2,5,1,4,6,4,9]))
# Out:
# [1, 2, 3, 4, 5, 6, 9, 0]

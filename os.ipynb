# %%
import os

# %%
os.name
# Out:
# 'nt'

# %%
#print(os.environ['HOME'])  # در لینوکس/مک
# یا
#print(os.environ)  # در ویندوز
home = os.environ.get('USERPROFILE') or os.get("home")
print(home)
# Out:
# C:\Users\ANA

# %%
import os
os.environ.items()
# لیست تمام متغیرهای محیطی
for key, value in os.environ.items():
    print(key)
    #if 'PATH' in key:  # فقط متغیرهایی که 'PATH' در نامشان هستند
        #print(f"{key} = {value}")
# Out:
# ALLUSERSPROFILE
# APPDATA
# CHROME_CRASHPAD_PIPE_NAME
# COMMONPROGRAMFILES
# COMMONPROGRAMFILES(X86)
# COMMONPROGRAMW6432
# COMPUTERNAME
# COMSPEC
# DRIVERDATA
# EFC_8832_1262719628
# EFC_8832_1592913036
# EFC_8832_2283032206
# EFC_8832_2775293581
# EFC_8832_3789132940
# ELECTRON_RUN_AS_NODE
# HOMEDRIVE
# HOMEPATH
# JPY_INTERRUPT_EVENT
# LOCALAPPDATA
# LOGONSERVER
# NUMBER_OF_PROCESSORS
# ONEDRIVE
# ORIGINAL_XDG_CURRENT_DESKTOP
# OS
# PATH
# PATHEXT
# PROCESSOR_ARCHITECTURE
# PROCESSOR_IDENTIFIER
# PROCESSOR_LEVEL
# PROCESSOR_REVISION
# PROGRAMDATA
# PROGRAMFILES
# PROGRAMFILES(X86)
# PROGRAMW6432
# PSMODULEPATH
# PUBLIC
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING
# PYTHONIOENCODING
# PYTHONUNBUFFERED
# PYTHON_FROZEN_MODULES
# SESSIONNAME
# SYSTEMDRIVE
# SYSTEMROOT
# TEMP
# TMP
# USERDOMAIN
# USERDOMAIN_ROAMINGPROFILE
# USERNAME
# USERPROFILE
# VSCODE_CODE_CACHE_PATH
# VSCODE_CRASH_REPORTER_PROCESS_TYPE
# VSCODE_CWD
# VSCODE_ESM_ENTRYPOINT
# VSCODE_HANDLES_UNCAUGHT_ERRORS
# ...

# %%
amir

# %%
os.environ.items()
# Out:
# ItemsView(environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\ANA\\AppData\\Roaming', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_16204_YSTOGEWBHEPCSUEM', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'DESKTOP-7D6EBML', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_19308_1592913036': '1', 'ELECTRON_RUN_AS_NODE': '1', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\ANA', 'JPY_INTERRUPT_EVENT': '1780', 'LOCALAPPDATA': 'C:\\Users\\ANA\\AppData\\Local', 'LOGONSERVER': '\\\\DESKTOP-7D6EBML', 'NUMBER_OF_PROCESSORS': '4', 'ONEDRIVE': 'C:\\Users\\ANA\\OneDrive', 'ONEDRIVECONSUMER': 'C:\\Users\\ANA\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\ANA\\AppData\\Local\\Programs\\Python\\Python313;c:\\Users\\ANA\\AppD
# ...

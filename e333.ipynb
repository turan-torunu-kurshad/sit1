# %%
def aval(s):
    d=int(s/2)
    e=list(range(2,d+1))
    for i in e:
       if not s % i == 0:
           e.remove(i) 
    if not len(e) == 0:
        return "adad is morakab"
    else:
        return "adad is aval"
q=aval(7)
print(q)
# Out:
# adad is morakab

# %%
w=[3,5,2]
w.remove(3)
w.remove(5)
w.remove(2)
len(w)
# Out:
# 0

# %%
def zog(a):
    d=[]
    c=d.copy()
    for i in a:
        if i%2==0:
            d.append(i)
    for i in d:
        for j in :
       
                        
    return d
e=zog([2,3,1,4,2,4,2,8,5,9,4,612,13,2.7,5])
print(e)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 13
#      10             d.append(i)
#      12     return d
# ---> 13 e=zog([2,3,1,4,2,4,2,8,5,9,4,612,13,2.7,5])
#      14 print(e)
#
# Cell In[41], line 10, in zog(a)
#       8         if i == j :
#       9             d.remove(i)
# ---> 10         d.append(i)
#      12 return d
#
# KeyboardInterrupt:

# %%
def d1(s):
    g=[]
    for i in s:
        if i not in g:
            g.append(i)
    return(g)
print(d1([4,2,1,6,3,1,2,8,5,9,3,1,2,12,13,18,17,2,13]))
# Out:
# [4, 2, 1, 6, 3, 8, 5, 9, 12, 13, 18, 17]

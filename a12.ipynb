# %%
import pandas as pd
s2=pd.Series({4:"mashin"
             ,2:"laptop"
             ,3:"divar"
             ,1:"banafsh"})
print(s2.values)
# Out:
# ['mashin' 'laptop' 'divar' 'banafsh']

# %%
p=[5,4,3,2,1,8,5,9,7,2,4,-1,6]
e=["dkdlkw","jodwkwij","nhdikdk","jnkkjwsnbj"]
o=pd. Series(e)
d=pd.Series(p)
s2=pd.Series({-1:"hhhu",1:"mashin",2:"lapjjjjjjjjjjjtop"})

# %%
s2.str.contains("j")
# Out:
# -1    False
#  1    False
#  2     True
# dtype: bool

# %%
import os 
import json

# %%
os.chdir("c:/Users/ANA/Desktop/project/amir-py-project")
os.getcwd()
# Out:
# 'c:\\Users\\ANA\\Desktop\\project\\amir-py-project'

# %%
print(os.path.exists("e3.ipynb"))
print(os.path.isfile("e3.ipynb "))
os.rmdir("e")
# Out:
# True
# True

# %%
os.path.basename('')
json_str = '{"name": "Ali", "age": 30}'
data = json.loads(json_str)
print(data)  # Output: {'name': 'Ali', 'age': 30}
# Out:
# {'name': 'Ali', 'age': 30}

# %%
# نام سیستم عامل (مثلاً: 'posix', 'nt', 'java')
#print(os.name)

# جداکننده مسیرها در این سیستم عامل (مثلاً: '/' در لینوکس، '\' در ویندوز)
#print(os.sep)

# متغیرهای محیطی (Environment Variables)
print(os.environ) # همه متغیرها
print(os.environ.get('PATH')) # گرفتن مسیر PATH 
                                   
# مسیر دایرکتوری جاری (Current Working Directory)
print(os.getcwd())

# تغییر دایرکتوری جاری
os.chdir('/path/to/new/directory')

# لیست کردن محتویات یک دایرکتوری
files_and_folders = os.listdir('.')
print(files_and_folders)

# ایجاد یک دایرکتوری جدید
os.mkdir('new_folder') # ایجاد یک پوشه
os.makedirs('parent/child/grandchild') # ایجاد چندین پوشه تو در تو

# حذف یک فایل
os.remove('unwanted_file.txt')

# حذف یک دایرکتوری خالی
os.rmdir('empty_folder')

# حذف یک دایرکتوری به همراه تمام محتویات آن (خطرناک!)
import shutil
shutil.rmtree('folder_to_delete')

# تغییر نام یک فایل یا دایرکتوری
os.rename('old_name.txt', 'new_name.txt')

# بررسی وجود یک فایل یا مسیر
if os.path.exists('my_file.txt'):
    print("File exists!")

# بررسی اینکه آیا یک مسیر، یک فایل است
if os.path.isfile('my_file.txt'):
    print("It's a file")

# بررسی اینکه آیا یک مسیر، یک دایرکتوری است
if os.path.isdir('my_directory'):
    print("It's a directory")

# گرفتن مسیر مطلق (Absolute Path) یک فایل
abs_path = os.path.abspath('my_file.txt')
print(abs_path)

# الحاق مسیرها به روش مستقل از سیستم عامل
new_path = os.path.join('parent', 'child', 'file.txt')
print(new_path) # در ویندوز: parent\child\file.txt | در لینوکس: parent/child/file.txt
# Out:
# nt
# \
# ...

# %%
os.chdir("c:/users/ana/desktop/project/amir-py-project")
os.getcwd()
# Out:
# 'c:\\users\\ana\\desktop\\project\\amir-py-project'

# %%
if os.path.isfile("a1.ipynb"):
    print("فایل موجود")
else:
    print("not")
# Out:
# فایل موجود

# %%
if os.path.isdir("os"):
    print("yes")
else:
    print("not")
# Out:
# yes

# %%
import os.path

path = "c:/users/ana/desktop/project/amir-py-project/a1.ipynb"

print(os.path.basename(path))     # 'report.pdf' (نام فایل)
print(os.path.dirname(path))      # '/home/user/documents' (مسیر دایرکتوری)
print(os.path.split(path))        # ('/home/user/documents', 'report.pdf')
# Out:
# a1.ipynb
# c:/users/ana/desktop/project/amir-py-project
# ('c:/users/ana/desktop/project/amir-py-project', 'a1.ipynb')

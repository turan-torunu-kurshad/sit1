# %%
def aval(a):
    r=list(range(2,int(a/2)+1))
    t=r.copy()
    print(r)
    for i in t:
        if a % i != 0 :
            r.remove(i)
        print(i),print(r)         
    if len(r) == 0: 
        print("adad is aval")
    else:
        print("adad is morakab")

# %%
aval(17)
# Out:
# [2, 3, 4, 5, 6, 7, 8]
# 2
# [3, 4, 5, 6, 7, 8]
# 3
# [4, 5, 6, 7, 8]
# 4
# [5, 6, 7, 8]
# 5
# [6, 7, 8]
# 6
# [7, 8]
# 7
# [8]
# 8
# []
# adad is aval

# %%
r=list(range(2,int(7/2)+1))
print(r)
# Out:
# [2, 3]

# %%
import os
os.getcwd()
os.
# Out:
# 'c:\\Users\\ANA\\Desktop\\project\\amir-py-project'

# %%
import re
result = re.search(r'\d+', 'abc123def')  # پیدا کردن عدد در رشته
print(result.group())  # خروجی: 123
# Out:
# 123

# %%
def aval1(b):
    r=list(range(2,int(b/2)+1))
    q=r.copy()
    for i in q:
        if b % i != 0 :
            r.append(i)
    if len(r) == (2*len(list(range(2,int(b/2)+1)))):
        print("adad is aval")
    else:
        print("adad is morakab")

# %%
import string
w=string.punctuation
print(type(w))
print(all(i in w for i in w))
# Out:
# <class 'str'>
# True

# %%
import math 
print(math.floor(65.47))
# Out:
# 65

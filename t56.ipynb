# %%
lst1=["ali","hasan","maykel"];lst4=["h","b","a"]
lst2=[ 45    ,34      ,56]
list3=list(zip(lst1,lst2,lst4))
print(list3[1])
# Out:
# ('hasan', 34, 'b')

# %%
lst5=list(zip(lst4,list3))
lst5
# Out:
# [('h', ('ali', 45, 'h')),
#  ('b', ('hasan', 34, 'b')),
#  ('a', ('maykel', 56, 'a'))]

# %%
for i,j,k in zip(lst1,lst2,lst4) :
    
    print(i,j,k)
# Out:
# ali 45 h
# hasan 34 b
# maykel 56 a

# %%
lst5=list(enumerate(lst1))
print(lst5)
# Out:
# [(0, 'ali'), (1, 'hasan'), (2, 'maykel')]

# %%
for i,j in enumerate(lst1):
    print(i)
# Out:
# 0
# 1
# 2
